# %%
import glob
import os
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from confidence_interval import calculate_confidence_interval, compare_model_accuracies

model_names = [
    "Simple1d",
    "Simple1dEmbedding",
    "Simple2d",
    "Simple2dEmbedding",
    "ResNet50",
    "ResNet50Embedding",
]
target_features = ["endianness", "instructionwidth_type"]

# %%
# Specify the directory containing the CSV files
directory = "./input/"  # Change this to your actual path
csv_files = glob.glob(os.path.join(directory, "Combined-*.csv"))
df_all = pd.concat((pd.read_csv(file) for file in csv_files), ignore_index=True)

for target_feature in target_features:
    model_results = {}
    arch_model_results = {}
    all_architectures = set()

    # Find all architecture columns
    arch_columns = [
        col
        for col in df_all.columns
        if col.startswith("test_accuracy_") and col != "test_accuracy"
    ]
    architectures = [col.replace("test_accuracy_", "") for col in arch_columns]
    all_architectures.update(architectures)

    for model_name in model_names:
        # Filter on model and target feature
        df = df_all[
            (df_all["validator.name"] == "train_test_separate_datasets")
            & (df_all["model.name"] == model_name)
            & (df_all["target_feature"] == target_feature)
        ].reset_index(drop=True)

        # Calculate the sum of all instance_count_* columns for each row
        samples_count_cols = [
            col for col in df.columns if col.startswith("instance_count_")
        ]
        df["total_samples_count"] = df[samples_count_cols].sum(axis=1).astype(int)

        # Ensure all rows have the same total instance count
        assert (
            df["total_samples_count"] == df["total_samples_count"].iloc[0]
        ).all(), "Not all rows have the same samples count."

        samples_per_run = int(df["total_samples_count"].iloc[0])

        model_mean, model_conf_95, _, _ = calculate_confidence_interval(
            accuracies=df["test_accuracy"], n_samples=samples_per_run, confidence=0.95
        )

        model_results[model_name] = (model_mean, model_conf_95)

        # Collect per-architecture results
        for arch_col in arch_columns:
            arch = arch_col.replace("test_accuracy_", "")
            if arch not in arch_model_results:
                arch_model_results[arch] = {}

            arch_mean = df[arch_col].mean()
            arch_std = df[arch_col].std()

            if not math.isnan(arch_mean):
                arch_model_results[arch][model_name] = (arch_mean, arch_std)

        print(arch_model_results)

    # Calculate mean accuracy across models for each architecture
    arch_means = {}
    for arch in all_architectures:
        values = []
        for model in model_names:
            if arch in arch_model_results and model in arch_model_results[arch]:
                values.append(arch_model_results[arch][model][0])
        if values:  # Only calculate if we have values
            arch_means[arch] = np.mean(values)

    # Sort architectures by mean accuracy (ascending)
    sorted_architectures = sorted(
        arch_means.keys(), key=lambda x: arch_means[x], reverse=False
    )

    # Create horizontal bar chart aggregated by architecture
    plt.figure(figsize=(9, 12))
    arch_means_list = []
    arch_stds_list = []

    for arch in sorted_architectures:
        arch_values = []
        for model in model_names:
            if arch in arch_model_results and model in arch_model_results[arch]:
                arch_values.append(arch_model_results[arch][model][0])
        if arch_values:  # Only calculate if we have values
            arch_means_list.append(np.mean(arch_values))
            arch_stds_list.append(np.std(arch_values))

    bars = plt.barh(
        range(len(sorted_architectures)),
        arch_means_list,
        xerr=arch_stds_list,
        capsize=5,
        color="yellowgreen",
    )
    plt.yticks(range(len(sorted_architectures)), sorted_architectures)
    plt.xlabel("Mean Accuracy Across All Models")
    plt.xlim(0, 1)
    plt.tight_layout()
    plt.savefig(f"output/combined-{target_feature.replace('_', '').lower()}-by-isa.png")

    # Create bar chart aggregated by model
    plt.figure(figsize=(9, 6))
    model_means = []
    model_conf_95s = []

    for model in model_names:
        mean, conf_95 = model_results[model]
        model_means.append(mean)
        model_conf_95s.append(conf_95)

    xticks = [model.replace("Embedding", "-E") for model in model_names]

    bars = plt.bar(
        range(len(model_names)),
        model_means,
        yerr=model_conf_95s,
        capsize=5,
        color="yellowgreen",
    )
    plt.xticks(range(len(model_names)), xticks, rotation=45)
    plt.ylabel("Mean Accuracy Across All ISAs")
    plt.ylim(0, 1)
    plt.tight_layout()
    plt.savefig(
        f"output/combined-{target_feature.replace('_', '').lower()}-by-model.png"
    )
# Out:
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, '68HC08': {'Simple1d': (np.float64(0.0), np.float64(0.0))}, '68HC11': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625))}, '8051': {}, 'ARC32eb': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272))}, 'ARC32el': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'ARM64': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'ARMeb': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272))}, 'AVR': {}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'Blackfin': {'Simple1d': (np.float64(0.45), np.float64(0.5104177855340405))}, 'CLIPPER': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327))}, 'CompactRISC': {'Simple1d': (np.float64(0.65), np.float64(0.4893604849295929))}, 'Cray': {}, 'Epiphany': {'Simple1d': (np.float64(0.8), np.float64(0.41039134083406165))}, 'FR-V': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'FR30': {'Simple1d': (np.float64(0.0), np.float64(0.0))}, 'FT32': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625))}, 'H8-300': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346))}, 'H8S': {}, 'HP-Focus': {}, 'HP-PA': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997896))}, 'IA-64': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625))}, 'IQ2000': {'Simple1d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'M32C': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327))}, 'M32R': {'Simple1d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'M68k': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894))}, 'M88k': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MCore': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327))}, 'MIPS16': {}, 'MIPSeb': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MIPSel': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MMIX': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MN10300': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MSP430': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'Mico32': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MicroBlaze': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'Moxie': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894))}, 'NDS32': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625))}, 'NIOS-II': {'Simple1d': (np.float64(0.15), np.float64(0.36634754853252327))}, 'PDP-11': {}, 'PIC10': {}, 'PIC16': {}, 'PIC18': {}, 'PIC24': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'PPCeb': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'PPCel': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'RISC-V': {'Simple1d': (np.float64(0.0), np.float64(0.0))}, 'RL78': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'ROMP': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272))}, 'RX': {'Simple1d': (np.float64(0.6), np.float64(0.5026246899500346))}, 'S-390': {'Simple1d': (np.float64(0.0), np.float64(0.0))}, 'SPARC': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894))}, 'STM8': {}, 'Stormy16': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'SuperH': {'Simple1d': (np.float64(0.95), np.float64(0.22360679774997896))}, 'TILEPro': {}, 'TLCS-90': {}, 'TMS320C2x': {}, 'TMS320C6x': {}, 'V850': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'VAX': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894))}, 'Visium': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'X86': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'X86-64': {'Simple1d': (np.float64(0.55), np.float64(0.5104177855340404))}, 'Xtensa': {}, 'XtensaEB': {'Simple1d': (np.float64(0.35), np.float64(0.4893604849295929))}, 'Z80': {'Simple1d': (np.float64(1.0), np.float64 ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929))}, '68HC08': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.48936048492959294))}, '68HC11': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.0), np.float64(0.0))}, '8051': {}, 'ARC32eb': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(0.2), np.float64(0.4103913408340617))}, 'ARC32el': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929))}, 'ARM64': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997896))}, 'ARMeb': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'AVR': {}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902))}, 'Blackfin': {'Simple1d': (np.float64(0.45), np.float64(0.5104177855340405)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'CLIPPER': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625))}, 'CompactRISC': {'Simple1d': (np.float64(0.65), np.float64(0.4893604849295929)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'Cray': {}, 'Epiphany': {'Simple1d': (np.float64(0.8), np.float64(0.41039134083406165)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'FR-V': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'FR30': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'FT32': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.6), np.float64(0.5026246899500346))}, 'H8-300': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple1dEmbedding': (np.float64(0.65), np.float64(0.4893604849295929))}, 'H8S': {}, 'HP-Focus': {}, 'HP-PA': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997896)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'IA-64': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.85), np.float64(0.36634754853252327))}, 'IQ2000': {'Simple1d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902))}, 'M32C': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'M32R': {'Simple1d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'M68k': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'M88k': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'MCore': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902))}, 'MIPS16': {}, 'MIPSeb': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'MIPSel': {'Simple1d': (np.float64(1 ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, '68HC08': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.48936048492959294)), 'Simple2d': (np.float64(0.0), np.float64(0.0))}, '68HC11': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.0), np.float64(0.0)), 'Simple2d': (np.float64(0.4), np.float64(0.5026246899500346))}, '8051': {}, 'ARC32eb': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(0.2), np.float64(0.4103913408340617)), 'Simple2d': (np.float64(0.0), np.float64(0.0))}, 'ARC32el': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'ARM64': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997896)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'ARMeb': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.8), np.float64(0.41039134083406165))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.6), np.float64(0.5026246899500346))}, 'AVR': {}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'Blackfin': {'Simple1d': (np.float64(0.45), np.float64(0.5104177855340405)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'CLIPPER': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'CompactRISC': {'Simple1d': (np.float64(0.65), np.float64(0.4893604849295929)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.15), np.float64(0.36634754853252327))}, 'Cray': {}, 'Epiphany': {'Simple1d': (np.float64(0.8), np.float64(0.41039134083406165)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.65), np.float64(0.4893604849295929))}, 'FR-V': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'FR30': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.35), np.float64(0.48936048492959283))}, 'FT32': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.6), np.float64(0.5026246899500346)), 'Simple2d': (np.float64(0.75), np.float64(0.4442616583193193))}, 'H8-300': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple1dEmbedding': (np.float64(0.65), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'H8S': {}, 'HP-Focus': {}, 'HP-PA': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997896)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64( ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.05), np.float64(0.22360679774997894))}, '68HC08': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.48936048492959294)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.3), np.float64(0.4701623459816272))}, '68HC11': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.0), np.float64(0.0)), 'Simple2d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple2dEmbedding': (np.float64(0.0), np.float64(0.0))}, '8051': {}, 'ARC32eb': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(0.2), np.float64(0.4103913408340617)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.0), np.float64(0.0))}, 'ARC32el': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929))}, 'ARM64': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997896)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902))}, 'ARMeb': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.8), np.float64(0.41039134083406165)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(0.6), np.float64(0.5026246899500346))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.6), np.float64(0.5026246899500346)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'AVR': {}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'Blackfin': {'Simple1d': (np.float64(0.45), np.float64(0.5104177855340405)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'CLIPPER': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'CompactRISC': {'Simple1d': (np.float64(0.65), np.float64(0.4893604849295929)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.15), np.float64(0.36634754853252327)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'Cray': {}, 'Epiphany': {'Simple1d': (np.float64(0.8), np.float64(0.41039134083406165)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.65), np.float64(0.4893604849295929)) ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.05), np.float64(0.22360679774997894)), 'ResNet50': (np.float64(0.25), np.float64(0.4442616583193193))}, '68HC08': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.48936048492959294)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.3), np.float64(0.4701623459816272)), 'ResNet50': (np.float64(0.0), np.float64(0.0))}, '68HC11': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.0), np.float64(0.0)), 'Simple2d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple2dEmbedding': (np.float64(0.0), np.float64(0.0)), 'ResNet50': (np.float64(0.0), np.float64(0.0))}, '8051': {}, 'ARC32eb': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(0.2), np.float64(0.4103913408340617)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.0), np.float64(0.0)), 'ResNet50': (np.float64(0.05), np.float64(0.22360679774997894))}, 'ARC32el': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, 'ARM64': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997896)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902)), 'ResNet50': (np.float64(0.7), np.float64(0.4701623459816272))}, 'ARMeb': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.8), np.float64(0.41039134083406165)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(0.6), np.float64(0.5026246899500346)), 'ResNet50': (np.float64(0.6), np.float64(0.5026246899500346))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.6), np.float64(0.5026246899500346)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.9), np.float64(0.30779350562554625))}, 'AVR': {}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.95), np.float64(0.22360679774997902))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, 'Blackfin': {'Simple1d': (np.float64(0.45), np.float64(0.5104177855340405)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.95), np.float64(0.223606797 ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.05), np.float64(0.22360679774997894)), 'ResNet50': (np.float64(0.25), np.float64(0.4442616583193193)), 'ResNet50Embedding': (np.float64(0.3), np.float64(0.4701623459816272))}, '68HC08': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.48936048492959294)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.3), np.float64(0.4701623459816272)), 'ResNet50': (np.float64(0.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.25), np.float64(0.4442616583193193))}, '68HC11': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.0), np.float64(0.0)), 'Simple2d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple2dEmbedding': (np.float64(0.0), np.float64(0.0)), 'ResNet50': (np.float64(0.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.05), np.float64(0.22360679774997894))}, '8051': {}, 'ARC32eb': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(0.2), np.float64(0.4103913408340617)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.0), np.float64(0.0)), 'ResNet50': (np.float64(0.05), np.float64(0.22360679774997894)), 'ResNet50Embedding': (np.float64(0.15), np.float64(0.36634754853252327))}, 'ARC32el': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.7), np.float64(0.4701623459816272))}, 'ARM64': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997896)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902)), 'ResNet50': (np.float64(0.7), np.float64(0.4701623459816272)), 'ResNet50Embedding': (np.float64(1.0), np.float64(0.0))}, 'ARMeb': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.8), np.float64(0.41039134083406165)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.85), np.float64(0.36634754853252327))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.4), np.float64(0.5026246899500346)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(0.6), np.float64(0.5026246899500346)), 'ResNet50': (np.float64(0.6), np.float64(0.5026246899500346)), 'ResNet50Embedding': (np.float64(0.8), np.float64(0.41039134083406165))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.6), np.float64(0.5026246899500346)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.9), np.float64(0.30779350562554625)), 'ResNet50Embedding': (np.float64(1.0), np.float64(0.0))}, 'AVR': {}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding':  ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, '68HC08': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, '68HC11': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, '8051': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'ARC32eb': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894))}, 'ARC32el': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283))}, 'ARM64': {'Simple1d': (np.float64(0.0), np.float64(0.0))}, 'ARMeb': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.95), np.float64(0.223606797749979))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272))}, 'AVR': {'Simple1d': (np.float64(0.75), np.float64(0.4442616583193193))}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'Blackfin': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'CLIPPER': {'Simple1d': (np.float64(0.25), np.float64(0.4442616583193193))}, 'CompactRISC': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'Cray': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'Epiphany': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894))}, 'FR-V': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'FR30': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283))}, 'FT32': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327))}, 'H8-300': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'H8S': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'HP-Focus': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625))}, 'HP-PA': {'Simple1d': (np.float64(0.65), np.float64(0.48936048492959283))}, 'IA-64': {'Simple1d': (np.float64(0.95), np.float64(0.223606797749979))}, 'IQ2000': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625))}, 'M32C': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'M32R': {'Simple1d': (np.float64(0.75), np.float64(0.4442616583193193))}, 'M68k': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'M88k': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MCore': {'Simple1d': (np.float64(0.6), np.float64(0.5026246899500346))}, 'MIPS16': {'Simple1d': (np.float64(0.0), np.float64(0.0))}, 'MIPSeb': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MIPSel': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327))}, 'MMIX': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MN10300': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MSP430': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'Mico32': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'MicroBlaze': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'Moxie': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'NDS32': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'NIOS-II': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'PDP-11': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'PIC10': {'Simple1d': (np.float64(0.0), np.float64(0.0))}, 'PIC16': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959294))}, 'PIC18': {'Simple1d': (np.float64(0.0), np.float64(0.0))}, 'PIC24': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272))}, 'PPCeb': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'PPCel': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'RISC-V': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'RL78': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'ROMP': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'RX': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'S-390': {'Simple1d': (np.float64(1.0), np.float64(0.0))}, 'SPARC': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327))}, 'STM8': {'Simple1d': (np.float64(0.1), np.float64(0.30779350562554625))}, 'Stormy16': {'Simple1d': (np.float64(0.5), np.float64(0.512989176042577))}, 'SuperH': {'Simple1d': (np.float64(0.5), np.float64(0.512989176042577))}, 'TILEPro': {'Simple1d': (np.float64(0.25), np.float64(0.4442616583193193))}, ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.15), np.float64(0.36634754853252327))}, '68HC08': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625))}, '68HC11': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, '8051': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARC32eb': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.223606797749979))}, 'ARC32el': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625))}, 'ARM64': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMeb': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'AVR': {'Simple1d': (np.float64(0.75), np.float64(0.4442616583193193)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577))}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.223606797749979))}, 'Blackfin': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902))}, 'CLIPPER': {'Simple1d': (np.float64(0.25), np.float64(0.4442616583193193)), 'Simple1dEmbedding': (np.float64(0.6), np.float64(0.5026246899500346))}, 'CompactRISC': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'Cray': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.65), np.float64(0.48936048492959283))}, 'Epiphany': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625))}, 'FR-V': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'FR30': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283)), 'Simple1dEmbedding': (np.float64(0.05), np.float64(0.22360679774997894))}, 'FT32': {'Simple1d': (np.float64(0.85), np.float64(0.36634754853252327)), 'Simple1dEmbedding': (np.float64(0.65), np.float64(0.48936048492959294))}, 'H8-300': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'H8S': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.85), np.float64(0.36634754853252327))}, 'HP-Focus': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(0.35), np.float64(0.4893604849295929))}, 'HP-PA': {'Simple1d': (np.float64(0.65), np.float64(0.48936048492959283)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'IA-64': {'Simple1d': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625))}, 'IQ2000': {'Simple1d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'M32C': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.65), np.float64(0.48936048492959283))}, 'M32R': {'Simple1d': (np.float64(0.75), np.float64(0.4442616583193193)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'M68k': {'Simp ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.15), np.float64(0.36634754853252327)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, '68HC08': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.9), np.float64(0.30779350562554625))}, '68HC11': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, '8051': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'ARC32eb': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple2d': (np.float64(0.0), np.float64(0.0))}, 'ARC32el': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.0), np.float64(0.0))}, 'ARM64': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625))}, 'ARMeb': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'AVR': {'Simple1d': (np.float64(0.75), np.float64(0.4442616583193193)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577)), 'Simple2d': (np.float64(0.3), np.float64(0.4701623459816272))}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'Blackfin': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'CLIPPER': {'Simple1d': (np.float64(0.25), np.float64(0.4442616583193193)), 'Simple1dEmbedding': (np.float64(0.6), np.float64(0.5026246899500346)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625))}, 'CompactRISC': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'Cray': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.65), np.float64(0.48936048492959283)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902))}, 'Epiphany': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.5), np.float64(0.512989176042577))}, 'FR-V': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0))}, 'FR30': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283)), 'Simple1dEmbedding': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple2d': (np.float64(0.15), np.float64(0.36634 ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.15), np.float64(0.36634754853252327)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.4), np.float64(0.5026246899500346))}, '68HC08': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, '68HC11': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, '8051': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARC32eb': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARC32el': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARM64': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMeb': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625))}, 'ARMhf': {'Simple1d': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.8), np.float64(0.41039134083406165))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'AVR': {'Simple1d': (np.float64(0.75), np.float64(0.4442616583193193)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577)), 'Simple2d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple2dEmbedding': (np.float64(0.45), np.float64(0.5104177855340405))}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'Blackfin': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0))}, 'CLIPPER': {'Simple1d': (np.float64(0.25), np.float64(0.4442616583193193)), 'Simple1dEmbedding': (np.float64(0.6), np.float64(0.5026246899500346)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(0.95), n ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.15), np.float64(0.36634754853252327)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.4), np.float64(0.5026246899500346)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, '68HC08': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, '68HC11': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, '8051': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, 'ARC32eb': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.0), np.float64(0.0))}, 'ARC32el': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.15), np.float64(0.36634754853252327))}, 'ARM64': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.25), np.float64(0.4442616583193193))}, 'ARMeb': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'ResNet50': (np.float64(1.0), np.float64(0.0))}, 'ARMhf': {'Simple1d': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.8), np.float64(0.41039134083406165)), 'ResNet50': (np.float64(0.35), np.float64(0.4893604849295929))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.7), np.float64(0.4701623459816272))}, 'AVR': {'Simple1d': (np.float64(0.75), np.float64(0.4442616583193193)), 'Simple1dEmbedding': (np.float64(0.5), np.float64(0.512989176042577)), 'Simple2d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple2dEmbedding': (np.float64(0.45), np.float64(0.5104177855340405)), 'ResNet50': (np.float64(0.9), np.float64(0.30779350562554625))}, 'Alpha': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.95), np.float64(0.22360679774997902))}, 'AxisCris': {'Simple1d': (np.float64(1.0), np. ...
# {'6502': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.15), np.float64(0.36634754853252327)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.4), np.float64(0.5026246899500346)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.75), np.float64(0.4442616583193193))}, '68HC08': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.95), np.float64(0.22360679774997902))}, '68HC11': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.85), np.float64(0.36634754853252327))}, '8051': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(1.0), np.float64(0.0))}, 'ARC32eb': {'Simple1d': (np.float64(0.05), np.float64(0.22360679774997894)), 'Simple1dEmbedding': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.7), np.float64(0.4701623459816272))}, 'ARC32el': {'Simple1d': (np.float64(0.35), np.float64(0.48936048492959283)), 'Simple1dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'Simple2d': (np.float64(0.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.15), np.float64(0.36634754853252327)), 'ResNet50Embedding': (np.float64(0.8), np.float64(0.41039134083406165))}, 'ARM64': {'Simple1d': (np.float64(0.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.1), np.float64(0.30779350562554625)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.25), np.float64(0.4442616583193193)), 'ResNet50Embedding': (np.float64(1.0), np.float64(0.0))}, 'ARMeb': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.7), np.float64(0.4701623459816272))}, 'ARMel': {'Simple1d': (np.float64(1.0), np.float64(0.0)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(1.0), np.float64(0.0)), 'Simple2dEmbedding': (np.float64(0.9), np.float64(0.30779350562554625)), 'ResNet50': (np.float64(1.0), np.float64(0.0)), 'ResNet50Embedding': (np.float64(0.95), np.float64(0.22360679774997902))}, 'ARMhf': {'Simple1d': (np.float64(0.95), np.float64(0.223606797749979)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(0.8), np.float64(0.41039134083406165)), 'ResNet50': (np.float64(0.35), np.float64(0.4893604849295929)), 'ResNet50Embedding': (np.float64(0.8), np.float64(0.41039134083406165))}, 'ARcompact': {'Simple1d': (np.float64(0.3), np.float64(0.4701623459816272)), 'Simple1dEmbedding': (np.float64(1.0), np.float64(0.0)), 'Simple2d': (np.float64(0.95), np.float64(0.22360679774997902)), 'Simple2dEmbedding': (np.float64(1.0), np.float64(0.0)), 'ResNet50': (np.float64(0.7), np.float64( ...

# %%
# Create a combined results table per architecture
for target_feature in target_features:
    model_results = {}
    arch_model_results = {}
    all_architectures = set()

    # Find all architecture columns
    arch_columns = [
        col
        for col in df_all.columns
        if col.startswith("test_accuracy_") and col != "test_accuracy"
    ]
    architectures = [col.replace("test_accuracy_", "") for col in arch_columns]
    all_architectures.update(architectures)

    for model_name in model_names:
        # Filter on model and target feature
        df = df_all[
            (df_all["validator.name"] == "train_test_separate_datasets")
            & (df_all["model.name"] == model_name)
            & (df_all["target_feature"] == target_feature)
        ].reset_index(drop=True)

        # Calculate the sum of all instance_count_* columns for each row
        samples_count_cols = [
            col for col in df.columns if col.startswith("instance_count_")
        ]
        df["total_samples_count"] = df[samples_count_cols].sum(axis=1).astype(int)

        # Ensure all rows have the same total instance count
        assert (
            df["total_samples_count"] == df["total_samples_count"].iloc[0]
        ).all(), "Not all rows have the same samples count."

        samples_per_run = int(df["total_samples_count"].iloc[0])

        model_mean, model_conf_95, _, _ = calculate_confidence_interval(
            accuracies=df["test_accuracy"], n_samples=samples_per_run, confidence=0.95
        )
        model_results[model_name] = (model_mean, model_conf_95)

        # Collect per-architecture results
        for arch_col in arch_columns:
            arch = arch_col.replace("test_accuracy_", "")
            if arch not in arch_model_results:
                arch_model_results[arch] = {}

            arch_mean = df[arch_col].mean()
            arch_std = df[arch_col].std()

            if not math.isnan(arch_mean):
                arch_model_results[arch][model_name] = (arch_mean, arch_std)

    # Calculate mean accuracy across models for each architecture
    arch_means = {}
    for arch in all_architectures:
        values = []
        for model in model_names:
            if arch in arch_model_results and model in arch_model_results[arch]:
                values.append(arch_model_results[arch][model][0])
        if values:  # Only calculate if we have values
            arch_means[arch] = np.mean(values)

    # Sort architectures by name (alphabetically)
    sorted_architectures = sorted(all_architectures, key=lambda x: x.lower())

    # Create the combined table
    table_string = "| Architecture |"
    for model in model_names:
        table_string += f" {model} |"
    table_string += "\n| ------------ |"
    table_string += " ------------: |" * len(model_names)

    # Add rows for each architecture
    for arch in sorted_architectures:
        for i, model in enumerate(model_names):
            if arch in arch_model_results and model in arch_model_results[arch]:
                mean, std = arch_model_results[arch][model]

                if math.isnan(mean):
                    continue

                if i == 0:
                    table_string += "\n"
                    table_string += f"| {arch} |"

                table_string += f" {int(round(mean * 20))}/20 |"

    # Add overall row
    table_string += "\n"
    table_string += "| **Overall** |"
    for model in model_names:
        mean, conf_95 = model_results[model]
        table_string += f" **{mean:.3f}±{conf_95:.3f}** |"
    table_string += "\n"

    # Save the table
    filename = (
        f"output/combined-{target_feature.replace('_', '').lower()}-combined-results.md"
    )
    with open(filename, "w") as f:
        f.write(table_string)

    print(f"Results table for {target_feature}:")
    print(table_string)
# Out:
# Results table for endianness:
# | Architecture | Simple1d | Simple1dEmbedding | Simple2d | Simple2dEmbedding | ResNet50 | ResNet50Embedding |
# | ------------ | ------------: | ------------: | ------------: | ------------: | ------------: | ------------: |
# | 6502 | 20/20 | 7/20 | 19/20 | 1/20 | 5/20 | 6/20 |
# | 68HC08 | 0/20 | 7/20 | 0/20 | 6/20 | 0/20 | 5/20 |
# | 68HC11 | 2/20 | 0/20 | 8/20 | 0/20 | 0/20 | 1/20 |
# | Alpha | 20/20 | 20/20 | 20/20 | 20/20 | 19/20 | 20/20 |
# | ARC32eb | 6/20 | 4/20 | 0/20 | 0/20 | 1/20 | 3/20 |
# | ARC32el | 20/20 | 7/20 | 20/20 | 7/20 | 20/20 | 14/20 |
# | ARcompact | 6/20 | 20/20 | 12/20 | 20/20 | 18/20 | 20/20 |
# | ARM64 | 20/20 | 19/20 | 20/20 | 19/20 | 14/20 | 20/20 |
# | ARMeb | 18/20 | 20/20 | 16/20 | 20/20 | 20/20 | 17/20 |
# | ARMel | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | ARMhf | 8/20 | 10/20 | 2/20 | 12/20 | 12/20 | 16/20 |
# | AxisCris | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | Blackfin | 9/20 | 20/20 | 20/20 | 20/20 | 19/20 | 20/20 |
# | CLIPPER | 17/20 | 18/20 | 20/20 | 20/20 | 19/20 | 19/20 |
# | CompactRISC | 13/20 | 20/20 | 3/20 | 20/20 | 14/20 | 20/20 |
# | Epiphany | 16/20 | 20/20 | 13/20 | 20/20 | 14/20 | 20/20 |
# | FR-V | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | FR30 | 0/20 | 20/20 | 7/20 | 20/20 | 12/20 | 20/20 |
# | FT32 | 2/20 | 12/20 | 15/20 | 20/20 | 16/20 | 19/20 |
# | H8-300 | 8/20 | 13/20 | 20/20 | 6/20 | 5/20 | 5/20 |
# | HP-PA | 1/20 | 20/20 | 7/20 | 20/20 | 19/20 | 20/20 |
# | IA-64 | 18/20 | 17/20 | 20/20 | 16/20 | 15/20 | 19/20 |
# | IQ2000 | 19/20 | 19/20 | 1/20 | 14/20 | 13/20 | 17/20 |
# | M32C | 17/20 | 20/20 | 20/20 | 16/20 | 17/20 | 17/20 |
# | M32R | 19/20 | 20/20 | 4/20 | 19/20 | 6/20 | 16/20 |
# | M68k | 1/20 | 20/20 | 6/20 | 20/20 | 0/20 | 20/20 |
# | M88k | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MCore | 17/20 | 19/20 | 19/20 | 18/20 | 8/20 | 15/20 |
# | Mico32 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MicroBlaze | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MIPSeb | 20/20 | 20/20 | 18/20 | 20/20 | 20/20 | 20/20 |
# | MIPSel | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MMIX | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MN10300 | 20/20 | 18/20 | 20/20 | 20/20 | 19/20 | 20/20 |
# | Moxie | 1/20 | 20/20 | 20/20 | 20/20 | 18/20 | 20/20 |
# | MSP430 | 20/20 | 20/20 | 17/20 | 20/20 | 14/20 | 20/20 |
# | NDS32 | 18/20 | 17/20 | 7/20 | 19/20 | 16/20 | 19/20 |
# | NIOS-II | 3/20 | 20/20 | 20/20 | 20/20 | 13/20 | 20/20 |
# | PIC24 | 20/20 | 6/20 | 20/20 | 11/20 | 20/20 | 16/20 |
# | PPCeb | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | PPCel | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | RISC-V | 0/20 | 18/20 | 1/20 | 16/20 | 5/20 | 7/20 |
# | RL78 | 20/20 | 16/20 | 19/20 | 18/20 | 18/20 | 12/20 |
# | ROMP | 6/20 | 5/20 | 13/20 | 0/20 | 13/20 | 0/20 |
# | RX | 12/20 | 20/20 | 19/20 | 20/20 | 19/20 | 20/20 |
# | S-390 | 0/20 | 20/20 | 8/20 | 20/20 | 10/20 | 18/20 |
# | SPARC | 1/20 | 20/20 | 14/20 | 20/20 | 17/20 | 20/20 |
# | Stormy16 | 20/20 | 20/20 | 20/20 | 20/20 | 19/20 | 20/20 |
# | SuperH | 19/20 | 20/20 | 4/20 | 20/20 | 9/20 | 20/20 |
# | V850 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | VAX | 1/20 | 3/20 | 16/20 | 4/20 | 16/20 | 11/20 |
# | Visium | 20/20 | 20/20 | 16/20 | 19/20 | 20/20 | 19/20 |
# | X86 | 20/20 | 20/20 | 17/20 | 20/20 | 20/20 | 20/20 |
# | X86-64 | 11/20 | 20/20 | 3/20 | 20/20 | 18/20 | 18/20 |
# | XtensaEB | 7/20 | 2/20 | 7/20 | 2/20 | 2/20 | 18/20 |
# | Z80 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | **Overall** | **0.675±0.033** | **0.836±0.028** | **0.724±0.031** | **0.824±0.029** | **0.743±0.035** | **0.846±0.024** |
#
# Results table for instructionwidth_type:
# | Architecture | Simple1d | Simple1dEmbedding | Simple2d | Simple2dEmbedding | ResNet50 | ResNet50Embedding |
# | ------------ | ------------: | ------------: | ------------: | ------------: | ------------: | ------------: |
# | 6502 | 20/20 | 3/20 | 19/20 | 8/20 | 20/20 | 15/20 |
# | 68HC08 | 20/20 | 18/20 | 18/20 | 20/20 | 20/20 | 19/20 |
# | 68HC11 | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 17/20 |
# | 8051 | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | Alpha | 20/20 | 20/20 | 20/20 | 20/20 | 19/20 | 20/20 |
# | ARC32eb | 1/20 | 19/20 | 0/20 | 20/20 | 0/20 | 14/20 |
# | ARC32el | 7/20 | 18/20 | 0/20 | 20/20 | 3/20 | 16/20 |
# | ARcompact | 6/20 | 20/20 | 19/20 | 20/20 | 14/20 | 20/20 |
# | ARM64 | 0/20 | 20/20 | 2/20 | 20/20 | 5/20 | 20/20 |
# | ARMeb | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 14/20 |
# | ARMel | 20/20 | 20/20 | 20/20 | 18/20 | 20/20 | 19/20 |
# | ARMhf | 19/20 | 20/20 | 19/20 | 16/20 | 7/20 | 16/20 |
# | AVR | 15/20 | 10/20 | 6/20 | 9/20 | 18/20 | 16/20 |
# | AxisCris | 20/20 | 19/20 | 19/20 | 20/20 | 20/20 | 19/20 |
# | Blackfin | 20/20 | 19/20 | 19/20 | 20/20 | 20/20 | 18/20 |
# | CLIPPER | 5/20 | 12/20 | 2/20 | 19/20 | 14/20 | 19/20 |
# | CompactRISC | 20/20 | 20/20 | 19/20 | 20/20 | 18/20 | 19/20 |
# | Cray | 20/20 | 13/20 | 19/20 | 19/20 | 19/20 | 17/20 |
# | Epiphany | 1/20 | 18/20 | 10/20 | 20/20 | 12/20 | 20/20 |
# | FR-V | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | FR30 | 7/20 | 1/20 | 3/20 | 0/20 | 7/20 | 0/20 |
# | FT32 | 17/20 | 13/20 | 18/20 | 15/20 | 18/20 | 16/20 |
# | H8-300 | 20/20 | 20/20 | 19/20 | 20/20 | 18/20 | 20/20 |
# | H8S | 20/20 | 17/20 | 18/20 | 19/20 | 16/20 | 19/20 |
# | HP-Focus | 18/20 | 7/20 | 18/20 | 13/20 | 4/20 | 3/20 |
# | HP-PA | 13/20 | 20/20 | 20/20 | 20/20 | 17/20 | 20/20 |
# | i860 | 0/20 | 4/20 | 1/20 | 2/20 | 4/20 | 10/20 |
# | IA-64 | 19/20 | 18/20 | 19/20 | 19/20 | 20/20 | 16/20 |
# | IQ2000 | 18/20 | 20/20 | 18/20 | 20/20 | 12/20 | 19/20 |
# | M32C | 20/20 | 13/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | M32R | 15/20 | 20/20 | 10/20 | 17/20 | 8/20 | 10/20 |
# | M68k | 20/20 | 20/20 | 19/20 | 20/20 | 19/20 | 20/20 |
# | M88k | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MCore | 12/20 | 17/20 | 4/20 | 18/20 | 16/20 | 17/20 |
# | Mico32 | 20/20 | 16/20 | 20/20 | 20/20 | 20/20 | 17/20 |
# | MicroBlaze | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MIPS16 | 0/20 | 1/20 | 1/20 | 0/20 | 4/20 | 0/20 |
# | MIPSeb | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MIPSel | 17/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MMIX | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | MN10300 | 20/20 | 20/20 | 18/20 | 20/20 | 20/20 | 20/20 |
# | Moxie | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | MSP430 | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | NDS32 | 20/20 | 20/20 | 19/20 | 20/20 | 15/20 | 20/20 |
# | NIOS-II | 20/20 | 20/20 | 1/20 | 20/20 | 11/20 | 20/20 |
# | PDP-11 | 20/20 | 19/20 | 17/20 | 20/20 | 9/20 | 17/20 |
# | PIC10 | 0/20 | 2/20 | 2/20 | 0/20 | 1/20 | 0/20 |
# | PIC16 | 7/20 | 9/20 | 4/20 | 1/20 | 2/20 | 4/20 |
# | PIC18 | 0/20 | 1/20 | 1/20 | 0/20 | 0/20 | 0/20 |
# | PIC24 | 6/20 | 19/20 | 20/20 | 13/20 | 19/20 | 10/20 |
# | PPCeb | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | PPCel | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | RISC-V | 20/20 | 18/20 | 20/20 | 20/20 | 20/20 | 20/20 |
# | RL78 | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | ROMP | 20/20 | 6/20 | 19/20 | 20/20 | 19/20 | 19/20 |
# | RX | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | S-390 | 20/20 | 19/20 | 9/20 | 20/20 | 10/20 | 20/20 |
# | SPARC | 17/20 | 20/20 | 11/20 | 20/20 | 16/20 | 20/20 |
# | STM8 | 2/20 | 9/20 | 1/20 | 9/20 | 3/20 | 11/20 |
# | Stormy16 | 10/20 | 10/20 | 16/20 | 19/20 | 9/20 | 17/20 |
# | SuperH | 10/20 | 19/20 | 13/20 | 19/20 | 5/20 | 11/20 |
# | TILEPro | 5/20 | 10/20 | 18/20 | 18/20 | 19/20 | 15/20 |
# | TLCS-90 | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | TMS320C2x | 20/20 | 20/20 | 18/20 | 20/20 | 10/20 | 19/20 |
# | TMS320C6x | 20/20 | 8/20 | 20/20 | 0/20 | 20/20 | 6/20 |
# | V850 | 20/20 | 14/20 | 19/20 | 20/20 | 20/20 | 18/20 |
# | VAX | 0/20 | 1/20 | 1/20 | 0/20 | 6/20 | 6/20 |
# | Visium | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | X86 | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 20/20 |
# | X86-64 | 18/20 | 20/20 | 19/20 | 20/20 | 17/20 | 20/20 |
# | Xtensa | 0/20 | 0/20 | 0/20 | 0/20 | 0/20 | 0/20 |
# | XtensaEB | 0/20 | 20/20 | 15/20 | 20/20 | 7/20 | 20/20 |
# | Z80 | 20/20 | 20/20 | 19/20 | 20/20 | 20/20 | 19/20 |
# | **Overall** | **0.743±0.027** | **0.795±0.026** | **0.732±0.041** | **0.829±0.022** | **0.733±0.030** | **0.806±0.026** |
